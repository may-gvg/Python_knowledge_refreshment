# %%
sc
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: </div>
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=337306706333968#setting/sparkui/1026-160005-hakuqb0a/driver-3238044447675518649">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>

# %% [markdown]
# 1. Dla zbioru recenzji Amazona wysupłaj te, które mają najwyższy rating (5.0) oraz zawierają słowo mouse.

# %%
path = "/databricks-datasets/amazon/data20K/part-*.gz.parquet"
rdd = spark.read.parquet(path).rdd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd_filtered = rdd.filter(lambda x: x.rating == 5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd_filtered2 = rdd.filter(lambda x: ("mouse" in x.review) & (x.rating == 5))
rdd_filtered2.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[76]: [Row(rating=5.0, review=&#34;This mouse is amazing, I had owned a Razer Naga, and a R.A.T. 7 mouse. And I am not afraid to say that this mouse takes the cake, for $20 it looks like its worth $80. The only issue i had was that the seller sent me a wireless version, but I don&#39;t mind because it works just as well. Also where you see silver on the mouse in reality it is glossy black, and the mouse looks better IRL then in the pictures. I will add on to this review in a month or so to check in.&#34;),
#  Row(rating=5.0, review=&#39;What can I say we all need a good mouse pad. This one looks and works great. It looks 3 D and I enjoy just looking at it.&#39;)]</div>

# %% [markdown]
# 2. Twoim zadaniem będzie policzyć najpopularniejsze żądania HTTP ze zbioru dostępnego w domyślnych danych Databricks. Mamy na myśli logi Apache z folderu /databricks-datasets/sample_logs/.
#
# Naszym punktem zainteresowań są tylko żądania dla requestów na endpointy o numerach od 300 do 399. Korzystając z poznanych tutaj transformacji (map, filter) oraz wyliczeń po ilości (countByValue), stwórz statystyki mówiące, które z tych endpointów są najbardziej popularne – z którymi z nich było najwięcej połączeń.

# %%
rdd2 = sc.wholeTextFiles("/databricks-datasets/sample_logs/part-*")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import re

rdd5 =(rdd2.map(lambda line: re.search('"*/endpoint_3.*"',line[1])))


sorted(
    rdd5.countByKey().items(),
    key=lambda el:el[1], reverse=True
)[:10]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[78]: [(&#39;/endpoint_322 HTTP/1.1&#34;&#39;, 8),
#  (&#39;/endpoint_368 HTTP/1.1&#34;&#39;, 5),
#  (&#39;/endpoint_381 HTTP/1.1&#34;&#39;, 4),
#  (&#39;/endpoint_314 HTTP/1.1&#34;&#39;, 4),
#  (&#39;/endpoint_356 HTTP/1.1&#34;&#39;, 4),
#  (&#39;/endpoint_343 HTTP/1.1&#34;&#39;, 4),
#  (&#39;/endpoint_304 HTTP/1.1&#34;&#39;, 2),
#  (&#39;/endpoint_345 HTTP/1.1&#34;&#39;, 1)]</div>

# %% [markdown]
# Zajmijmy się zbiorem piosenek, który znajdziesz pod ścieżką /databricks-datasets/songs/data-001. Z kolekcji całych plików (wholeTextFiles) stwórz RDD, a następnie korzystając z mapowania, przekształć na RDD zawierającą nazwy plików i ich rozmiar.

# %%
# %fs
ls /databricks-datasets/songs/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/songs/README.md</td><td>README.md</td><td>1719</td></tr><tr><td>dbfs:/databricks-datasets/songs/data-001/</td><td>data-001/</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/songs/data-002/</td><td>data-002/</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# Po raz kolejny zajmijmy się zbiorem piosenek, który znajdziesz pod ścieżką /databricks-datasets/songs/data-001. Z kolekcji całych plików (wholeTextFiles) stwórz RDD, a następnie korzystając z mapowania, przekształć na RDD zawierającą nazwy plików i ich rozmiar.

# %%
rdd_files = sc.wholeTextFiles("/databricks-datasets/songs/data-001")

rdd_files.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[79]
\tSOIVREI12AC468C0E3\t164.833\t102.329\t5\t0.508\tI Quit My Pretty Mama\t0\t373410\nARORFTD1187B99F7D4\tnan\tnan\t台北, Taiwan\tEpitaph\t215.95383\t5.045\t7\t0.573\t-6.728\tReturn To Reality\t0.0\tSOEWJZN12AC3DF4A65\t204.196\t113.745\t4\t1.0\tSet Your Spirit Free\t0\t837454\nAR8UA7Z1187B9AD9C9\t48.10751\t-1.68447\tRennes\tÉtienne Daho\t303.62077\t0.0\t1\t0.755\t-11.422\tLive Ed\tnan\tSORSGDF12A6D4F3B7F\t303.621\t113.924\t3\t1.0\tStay with me (Live 1989)\t0\t138182\nARMLOSJ1187B98B08C\t52.08399\t4.31741\tThe Hague, Netherlands\tAnouk\t266.60526\t0.27\t4\t0.466\t-8.759\tUrban Solitude\t0.592213231387\tSOUHUSP12AB01858D3\t246.091\t131.724\t4\t0.803\tIt Wasn\&#39;t Me\t0\t882513\nARN1ETG1187FB41238\tnan\tnan\t\tRivermaya\t326.19057\t0.09\t2\t1.0\t-8.587\tGreatest Hits\t0.355521077989\tSOXISCD12AB018EF71\t314.485\t157.781\t4\t1.0\tIf\t1997\t364624\nARQWEFN12086C16CBB\tnan\tnan\t\tIgnominious Incarceration\t51.04281\t2.368\t4\t0.0\t-5.403\tOf Winter Born\t0.367273415809\tSOXOTMK12AB01889A6\t51.043\t117.781\t4\t0.937\tThe Beginning\t2009\t54408\nARYCW9Z11C8A42B088\tnan\tnan\t\tRobert Pattinson\t129.4624\t0.0\t8\t0.023\t-10.231\tHow To Be [Original Motion Picture Soundtrack]\t0.523445682991\tSOZIWST12A58A7C80F\t129.462\t86.782\t5\t0.394\tDoin\&#39; Fine\t0\t756327\nAR19DC41187B9A1BED\tnan\tnan\t\tAxel Krygier\t253.33506\t0.2\t2\t0.16\t-7.634\tSecreto y Malibú\t0.299877488274\tSOMLLWM12A6D4F4DC7\t240.292\t106.174\t4\t0.391\tFinal\t2003\t514414\nARLGLB31187B9AE0C2\t38.2589\t-92.43659\tMissouri\tDeep Thinkers\t237.76608\t0.0\t4\t0.308\t-5.864\tEastern Conference All-Stars IV\t0 ...

# %%
rdd_map3 = rdd_files.map(lambda text: (text[0], len(text[1])))

rdd_map3.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[81]: [(&#39;dbfs:/databricks-datasets/songs/data-001/header.txt&#39;, 377),
#  (&#39;dbfs:/databricks-datasets/songs/data-001/part-00000&#39;, 52793),
#  (&#39;dbfs:/databricks-datasets/songs/data-001/part-00001&#39;, 52414),
#  (&#39;dbfs:/databricks-datasets/songs/data-001/part-00002&#39;, 51753),
#  (&#39;dbfs:/databricks-datasets/songs/data-001/part-00003&#39;, 50513)]</div>

# %% [markdown]
# Podejrzyj zbiór adult poleceniem take. Z czego składa się każdy element? To tzw. Row z elementami oznaczonymi _c0, _c1 itd. Są to nienazwane kolumny (można oczywiście je nazwać przy pomocy API DataFrame). Dla nas najważniejsze będą:
#
# _c0: wiek
# _c5: stan cywilny
# _c6: zawód
#
# Na początek stwórz RDD, które będzie zawierać tylko takie osoby, które są rozwiedzione: _c5 zawiera słowo Divorced. Wypisz 10 pierwszych osób z tego zestawienia, posortowanych według wieku rosnąco.
#
# Teraz dokonaj dalszej analizy. Weź pod uwagę zawód. Oblicz, jakim procentem dla tych wszystkich rozwiedzionych są osoby, które pracują na stanowiskach menedżerskich: właściwością _c6 jest Exec-managerial.

# %%
rdd = spark.read.csv("/databricks-datasets/adult/adult.data").rdd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd.take(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[83]: [Row(_c0=&#39;39&#39;, _c1=&#39; State-gov&#39;, _c2=&#39; 77516&#39;, _c3=&#39; Bachelors&#39;, _c4=&#39; 13&#39;, _c5=&#39; Never-married&#39;, _c6=&#39; Adm-clerical&#39;, _c7=&#39; Not-in-family&#39;, _c8=&#39; White&#39;, _c9=&#39; Male&#39;, _c10=&#39; 2174&#39;, _c11=&#39; 0&#39;, _c12=&#39; 40&#39;, _c13=&#39; United-States&#39;, _c14=&#39; &lt;=50K&#39;)]</div>

# %%
 #   _c0: wiek
 #   _c5: stan cywilny
 #   _c6: zawód
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd2 = rdd.map(lambda x: [x[i] for i in [0,5,6]])
rdd2.take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[85]: [[&#39;39&#39;, &#39; Never-married&#39;, &#39; Adm-clerical&#39;],
#  [&#39;50&#39;, &#39; Married-civ-spouse&#39;, &#39; Exec-managerial&#39;],
#  [&#39;38&#39;, &#39; Divorced&#39;, &#39; Handlers-cleaners&#39;],
#  [&#39;53&#39;, &#39; Married-civ-spouse&#39;, &#39; Handlers-cleaners&#39;],
#  [&#39;28&#39;, &#39; Married-civ-spouse&#39;, &#39; Prof-specialty&#39;]]</div>

# %%
# Na początek stwórz RDD, które będzie zawierać tylko takie osoby, które są rozwiedzione: _c5 zawiera słowo Divorced.
# Wypisz 10 pierwszych osób z tego zestawienia, posortowanych według wieku rosnąco.
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rdd3 = rdd2.filter(lambda x: (" Divorced" == x[1]) )
rdd3.takeOrdered(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[87]: [[&#39;18&#39;, &#39; Divorced&#39;, &#39; Other-service&#39;],
#  [&#39;19&#39;, &#39; Divorced&#39;, &#39; Craft-repair&#39;],
#  [&#39;19&#39;, &#39; Divorced&#39;, &#39; Exec-managerial&#39;],
#  [&#39;19&#39;, &#39; Divorced&#39;, &#39; Other-service&#39;],
#  [&#39;19&#39;, &#39; Divorced&#39;, &#39; Other-service&#39;],
#  [&#39;19&#39;, &#39; Divorced&#39;, &#39; Other-service&#39;],
#  [&#39;19&#39;, &#39; Divorced&#39;, &#39; Sales&#39;],
#  [&#39;20&#39;, &#39; Divorced&#39;, &#39; ?&#39;],
#  [&#39;20&#39;, &#39; Divorced&#39;, &#39; ?&#39;],
#  [&#39;20&#39;, &#39; Divorced&#39;, &#39; Adm-clerical&#39;]]</div>

# %% [markdown]
# Teraz dokonaj dalszej analizy. Weź pod uwagę zawód. Oblicz, jakim procentem dla tych wszystkich rozwiedzionych są osoby, które pracują na stanowiskach menedżerskich: właściwością _c6 jest Exec-managerial.

# %%
rdd4 = rdd3.filter(lambda x: (" Exec-managerial" == x[2]) )
rdd4.take(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[88]: [[&#39;43&#39;, &#39; Divorced&#39;, &#39; Exec-managerial&#39;],
#  [&#39;39&#39;, &#39; Divorced&#39;, &#39; Exec-managerial&#39;]]</div>

# %%
#no. divorced
divorced = rdd3.count()
# no. of div managers 
divorced_manager = rdd4.count()
wynik = (100*divorced_manager)/divorced 
print(f"procent rozwiedzionych managerów: {wynik:.2f} %")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">procent rozwiedzionych managerów: 13.59 %
# </div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
